# %% [markdown]
# ## A gentle 10-minute introduction to Ray AI Runitime (Ray AIR)
#
# As part of Ray 2.0, Ray AI Runtime (AIR) is an open-source toolkit for building end-to-end ML applications. By leveraging Ray, its distributed compute capabilities, and its library ecosystem, Ray AIR brings scalability and programmability to ML platforms.
#
# The main focuses of the Ray AI Runtime:
#  * Ray AIR focuses on providing scalability by leveraging Ray’s distributed compute layer for ML workloads.
#  * It is designed to interoperate with other systems for storage and metadata needs.
#
# Ray AIR consists of 5 key components:
#
#  * Data processing (Ray Data)
#  * Model Training (Ray Train)
#  * Reinforcement Learning (Ray RLlib)
#  * Hyperparameter Tuning (Ray Tune)
#  * Model Serving (Ray Serve).
#
#  <img src = "images/ai_runtime.jpeg" width="60%" height="30%">
#
#  ### Learning objectives:
#   * Get a quick and introductory feel for Ray AIR as unified toolkit to write and end-to-end ML application in a single Python script or notebook
#   * Get an exposure to Ray data for data ingestion
#   * Learn about out-of-box familiar Preprocessors
#   * Load model from checkpoint, use batch inference
#   * Use `PredictorDeployment` class to deploy model and use online inference

# %%
import logging, os, random, warnings
from pprint import pprint
import ray
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

from ray.data.preprocessors import StandardScaler

# %%
warnings.filterwarnings("ignore")
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
if ray.is_initialized:
    ray.shutdown()
context = ray.init(logging_level=logging.ERROR)
pprint(context)
# Out:
# RayContext(dashboard_url='127.0.0.1:8268', python_version='3.8.13', ray_version='3.0.0.dev0', ray_commit='{{RAY_COMMIT_SHA}}', address_info={'node_ip_address': '127.0.0.1', 'raylet_ip_address': '127.0.0.1', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2022-07-18_21-02-48_546719_70340/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-07-18_21-02-48_546719_70340/sockets/raylet', 'webui_url': '127.0.0.1:8268', 'session_dir': '/tmp/ray/session_2022-07-18_21-02-48_546719_70340', 'metrics_export_port': 65530, 'gcs_address': '127.0.0.1:65503', 'address': '127.0.0.1:65503', 'dashboard_agent_listen_port': 52365, 'node_id': '4a225d65b457a9b0566e99c1b6d70ca6e0f6f369fb83c01166d68deb'})

# %%
print(f"Dashboard url: http://{context.address_info['webui_url']}")
# Out:
# Dashboard url: http://127.0.0.1:8268

# %% [markdown]
# ### Create Ray data from Pandas dataset

# %%
import ray
import pandas as pd
from ray.air import train_test_split

# Split data into train and validation.
dataset = ray.data.read_csv("s3://anonymous@air-example-data/breast_cancer.csv")
train_dataset, valid_dataset = train_test_split(dataset, test_size=0.3)
test_dataset = valid_dataset.drop_columns(["target"])
# Out:
# Map_Batches: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 74.72it/s]

# %% [markdown]
# ### Create Preprocessors

# %%
# Create a preprocessor to scale some columns
from ray.data.preprocessors import StandardScaler

columns_to_scale = ["mean radius", "mean texture"]
preprocessor = StandardScaler(columns=columns_to_scale)

# %% [markdown]
# ### Create Trainers

# %%
from ray.train.xgboost import XGBoostTrainer

trainer = XGBoostTrainer(
    scaling_config={
        # Number of workers to use for data parallelism.
        "num_workers": 2,
        # Whether to use GPU acceleration.
        "use_gpu": False,
    },
    label_column="target",
    num_boost_round=20,
    params={
        # XGBoost specific params
        "objective": "binary:logistic",
        "eval_metric": ["logloss", "error"],
    },
    datasets={"train": train_dataset, "valid": valid_dataset},
    preprocessor=preprocessor,
)
result = trainer.fit()
print(result.metrics)
# Out:
# == Status ==<br>Current time: 2022-07-18 21:04:28 (running for 00:00:06.52)<br>Memory usage on this node: 26.1/64.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/10 CPUs, 0/0 GPUs, 0.0/33.53 GiB heap, 0.0/2.0 GiB objects<br>Result logdir: /Users/jules/ray_results/XGBoostTrainer_2022-07-18_21-04-21<br>Number of trials: 1/1 (1 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                </th><th>status    </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train-logloss</th><th style="text-align: right;">  train-error</th><th style="text-align: right;">  valid-logloss</th></tr>
# </thead>
# <tbody>
# <tr><td>XGBoostTrainer_de37e_00000</td><td>TERMINATED</td><td>127.0.0.1:70815</td><td style="text-align: right;">    20</td><td style="text-align: right;">         4.78056</td><td style="text-align: right;">      0.0184957</td><td style="text-align: right;">            0</td><td style="text-align: right;">      0.0893879</td></tr>
# </tbody>
# </table><br><br>
# (XGBoostTrainer pid=70815) 2022-07-18 21:04:22,789	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# (XGBoostTrainer pid=70815) 2022-07-18 21:04:24,434	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (_RemoteRayXGBoostActor pid=70829) 2022-07-18 21:04:25,498	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=70829)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=70829)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=70829)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=70829)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=70829)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=70829)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=70829)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=70829)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=70829)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=70829)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=70829)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=70829)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=70829)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=70829)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=70829)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=70829)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=70828) 2022-07-18 21:04:25,547	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=70828)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=70828)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=70828)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=70828)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=70828)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=70828)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=70828)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=70828)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=70828)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=70828)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=70828)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=70828)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=70828)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=70828)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=70828)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=70828)     traceback.print_stack()
# (XGBoostTrainer pid=70815) 2022-07-18 21:04:25,660	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (_RemoteRayXGBoostActor pid=70829) [21:04:25] task [xgboost.ray]:5320760432 got new rank 1
# (_RemoteRayXGBoostActor pid=70828) [21:04:25] task [xgboost.ray]:5793762512 got new rank 0
# Result for XGBoostTrainer_de37e_00000:
#   date: 2022-07-18_21-04-27
#   done: false
#   experiment_id: fa960636b34145a689be5de2568fa53a
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 70815
#   should_checkpoint: true
#   time_since_restore: 4.643670082092285
#   time_this_iter_s: 4.643670082092285
#   time_total_s: 4.643670082092285
#   timestamp: 1658203467
#   timesteps_since_restore: 0
#   train-error: 0.02261306532663317
#   train-logloss: 0.464117960489575
#   training_iteration: 1
#   trial_id: de37e_00000
#   valid-error: 0.11695906432748537
#   valid-logloss: 0.5025240946234318
#   warmup_time: 0.0028710365295410156
# (XGBoostTrainer pid=70815) 2022-07-18 21:04:27,576	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 3.15 seconds (1.91 pure XGBoost training time).
# Result for XGBoostTrainer_de37e_00000:
#   date: 2022-07-18_21-04-27
#   done: true
#   experiment_id: fa960636b34145a689be5de2568fa53a
#   experiment_tag: '0'
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 70815
#   should_checkpoint: true
#   time_since_restore: 4.780561208724976
#   time_this_iter_s: 0.006635904312133789
#   time_total_s: 4.780561208724976
#   timestamp: 1658203467
#   timesteps_since_restore: 0
#   train-error: 0.0
#   train-logloss: 0.01849572773292735
#   training_iteration: 20
#   trial_id: de37e_00000
#   valid-error: 0.04093567251461988
#   valid-logloss: 0.08938791319913073
#   warmup_time: 0.0028710365295410156
#
# {'train-logloss': 0.01849572773292735, 'train-error': 0.0, 'valid-logloss': 0.08938791319913073, 'valid-error': 0.04093567251461988, 'time_this_iter_s': 0.006635904312133789, 'should_checkpoint': True, 'done': True, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 20, 'trial_id': 'de37e_00000', 'experiment_id': 'fa960636b34145a689be5de2568fa53a', 'date': '2022-07-18_21-04-27', 'timestamp': 1658203467, 'time_total_s': 4.780561208724976, 'pid': 70815, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {}, 'time_since_restore': 4.780561208724976, 'timesteps_since_restore': 0, 'iterations_since_restore': 20, 'warmup_time': 0.0028710365295410156, 'experiment_tag': '0'}

# %% [markdown]
# ### Create Tuner for hyperparameter search

# %%
from ray import tune

param_space = {"params": {"max_depth": tune.randint(1, 9)}}
metric = "train-logloss"

# %%
from ray.tune.tuner import Tuner, TuneConfig
from ray.air.config import RunConfig

tuner = Tuner(
    trainer,
    param_space=param_space,
    tune_config=TuneConfig(num_samples=5, metric=metric, mode="min"),
)
# Execute tuning.
result_grid = tuner.fit()

# Fetch the best result.
best_result = result_grid.get_best_result()
print("Best Result:", best_result)
# Out:
# == Status ==<br>Current time: 2022-07-18 21:04:54 (running for 00:00:12.65)<br>Memory usage on this node: 26.6/64.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/10 CPUs, 0/0 GPUs, 0.0/33.53 GiB heap, 0.0/2.0 GiB objects<br>Current best trial: ea7f4_00001 with train-logloss=0.01841634292981527 and parameters={'params': {'max_depth': 5}}<br>Result logdir: /Users/jules/ray_results/XGBoostTrainer_2022-07-18_21-04-41<br>Number of trials: 5/5 (5 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                </th><th>status    </th><th>loc            </th><th style="text-align: right;">  params/max_depth</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train-logloss</th><th style="text-align: right;">  train-error</th><th style="text-align: right;">  valid-logloss</th></tr>
# </thead>
# <tbody>
# <tr><td>XGBoostTrainer_ea7f4_00000</td><td>TERMINATED</td><td>127.0.0.1:70856</td><td style="text-align: right;">                 3</td><td style="text-align: right;">    20</td><td style="text-align: right;">         2.70495</td><td style="text-align: right;">      0.0215151</td><td style="text-align: right;">    0        </td><td style="text-align: right;">      0.0765915</td></tr>
# <tr><td>XGBoostTrainer_ea7f4_00001</td><td>TERMINATED</td><td>127.0.0.1:70865</td><td style="text-align: right;">                 5</td><td style="text-align: right;">    20</td><td style="text-align: right;">         3.58326</td><td style="text-align: right;">      0.0184163</td><td style="text-align: right;">    0        </td><td style="text-align: right;">      0.105782 </td></tr>
# <tr><td>XGBoostTrainer_ea7f4_00002</td><td>TERMINATED</td><td>127.0.0.1:70866</td><td style="text-align: right;">                 3</td><td style="text-align: right;">    20</td><td style="text-align: right;">         3.5276 </td><td style="text-align: right;">      0.0215151</td><td style="text-align: right;">    0        </td><td style="text-align: right;">      0.0765915</td></tr>
# <tr><td>XGBoostTrainer_ea7f4_00003</td><td>TERMINATED</td><td>127.0.0.1:70942</td><td style="text-align: right;">                 1</td><td style="text-align: right;">    20</td><td style="text-align: right;">         5.27101</td><td style="text-align: right;">      0.0955215</td><td style="text-align: right;">    0.0175879</td><td style="text-align: right;">      0.112007 </td></tr>
# <tr><td>XGBoostTrainer_ea7f4_00004</td><td>TERMINATED</td><td>127.0.0.1:70953</td><td style="text-align: right;">                 6</td><td style="text-align: right;">    20</td><td style="text-align: right;">         4.48254</td><td style="text-align: right;">      0.0184957</td><td style="text-align: right;">    0        </td><td style="text-align: right;">      0.0893879</td></tr>
# </tbody>
# </table><br><br>
# (XGBoostTrainer pid=70856) 2022-07-18 21:04:43,086	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# (XGBoostTrainer pid=70856) 2022-07-18 21:04:43,152	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (_RemoteRayXGBoostActor pid=70871) 2022-07-18 21:04:44,233	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=70871)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=70871)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=70871)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=70871)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=70871)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=70871)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=70871)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=70871)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=70871)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=70871)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=70871)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=70871)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=70871)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=70871)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=70871)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=70871)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=70872) 2022-07-18 21:04:44,235	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=70872)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=70872)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=70872)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=70872)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=70872)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=70872)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=70872)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=70872)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=70872)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=70872)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=70872)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=70872)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=70872)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=70872)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=70872)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=70872)     traceback.print_stack()
# (XGBoostTrainer pid=70856) 2022-07-18 21:04:44,353	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (XGBoostTrainer pid=70865) 2022-07-18 21:04:44,317	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# (XGBoostTrainer pid=70866) 2022-07-18 21:04:44,317	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# (XGBoostTrainer pid=70865) 2022-07-18 21:04:44,400	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (XGBoostTrainer pid=70866) 2022-07-18 21:04:44,409	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (_RemoteRayXGBoostActor pid=70871) [21:04:44] task [xgboost.ray]:5183462464 got new rank 0
# (_RemoteRayXGBoostActor pid=70872) [21:04:44] task [xgboost.ray]:5147839696 got new rank 1
# Result for XGBoostTrainer_ea7f4_00000:
#   date: 2022-07-18_21-04-45
#   done: false
#   experiment_id: db2f8c822d7441789c3d9b68ec2b0d2f
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 70856
#   should_checkpoint: true
#   time_since_restore: 2.301074981689453
#   time_this_iter_s: 2.301074981689453
#   time_total_s: 2.301074981689453
#   timestamp: 1658203485
#   timesteps_since_restore: 0
#   train-error: 0.03517587939698492
#   train-logloss: 0.47431553248784053
#   training_iteration: 1
#   trial_id: ea7f4_00000
#   valid-error: 0.09941520467836257
#   valid-logloss: 0.5004687657830311
#   warmup_time: 0.0028541088104248047
# (_RemoteRayXGBoostActor pid=70910) 2022-07-18 21:04:45,667	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=70910)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=70910)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=70910)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=70910)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=70910)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=70910)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=70910)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=70910)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=70910)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=70910)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=70910)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=70910)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=70910)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=70910)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=70910)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=70910)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=70912) 2022-07-18 21:04:45,687	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=70912)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=70912)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=70912)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=70912)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=70912)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=70912)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=70912)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=70912)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=70912)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=70912)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=70912)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=70912)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=70912)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=70912)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=70912)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=70912)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=70914) 2022-07-18 21:04:45,687	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=70914)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=70914)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=70914)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=70914)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=70914)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=70914)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=70914)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=70914)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=70914)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=70914)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=70914)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=70914)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=70914)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=70914)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=70914)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=70914)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=70913) 2022-07-18 21:04:45,688	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=70913)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=70913)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=70913)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=70913)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=70913)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=70913)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=70913)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=70913)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=70913)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=70913)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=70913)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=70913)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=70913)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=70913)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=70913)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=70913)     traceback.print_stack()
# (XGBoostTrainer pid=70856) 2022-07-18 21:04:45,796	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 2.66 seconds (1.44 pure XGBoost training time).
# (XGBoostTrainer pid=70865) 2022-07-18 21:04:46,610	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (XGBoostTrainer pid=70866) 2022-07-18 21:04:46,611	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (_RemoteRayXGBoostActor pid=70910) [21:04:46] task [xgboost.ray]:5132655680 got new rank 0
# (_RemoteRayXGBoostActor pid=70912) [21:04:46] task [xgboost.ray]:5251898720 got new rank 1
# (_RemoteRayXGBoostActor pid=70914) [21:04:46] task [xgboost.ray]:4829469808 got new rank 1
# (_RemoteRayXGBoostActor pid=70913) [21:04:46] task [xgboost.ray]:6071352576 got new rank 0
# Result for XGBoostTrainer_ea7f4_00000:
#   date: 2022-07-18_21-04-45
#   done: true
#   experiment_id: db2f8c822d7441789c3d9b68ec2b0d2f
#   experiment_tag: 0_max_depth=3
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 70856
#   should_checkpoint: true
#   time_since_restore: 2.7049450874328613
#   time_this_iter_s: 0.008007049560546875
#   time_total_s: 2.7049450874328613
#   timestamp: 1658203485
#   timesteps_since_restore: 0
#   train-error: 0.0
#   train-logloss: 0.02151511543566108
#   training_iteration: 20
#   trial_id: ea7f4_00000
#   valid-error: 0.03508771929824561
#   valid-logloss: 0.07659151291540056
#   warmup_time: 0.0028541088104248047
#
# Result for XGBoostTrainer_ea7f4_00001:
#   date: 2022-07-18_21-04-47
#   done: false
#   experiment_id: 5f8025068bcb4ed4ac66cbc01b1c4265
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 70865
#   should_checkpoint: true
#   time_since_restore: 3.318230152130127
#   time_this_iter_s: 3.318230152130127
#   time_total_s: 3.318230152130127
#   timestamp: 1658203487
#   timesteps_since_restore: 0
#   train-error: 0.02261306532663317
#   train-logloss: 0.465611254524945
#   training_iteration: 1
#   trial_id: ea7f4_00001
#   valid-error: 0.0935672514619883
#   valid-logloss: 0.5058815336366843
#   warmup_time: 0.0031299591064453125
#
# Result for XGBoostTrainer_ea7f4_00002:
#   date: 2022-07-18_21-04-47
#   done: false
#   experiment_id: 45c11517546e48fba5953b3460d0119a
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 70866
#   should_checkpoint: true
#   time_since_restore: 3.320551872253418
#   time_this_iter_s: 3.320551872253418
#   time_total_s: 3.320551872253418
#   timestamp: 1658203487
#   timesteps_since_restore: 0
#   train-error: 0.03517587939698492
#   train-logloss: 0.47431553248784053
#   training_iteration: 1
#   trial_id: ea7f4_00002
#   valid-error: 0.09941520467836257
#   valid-logloss: 0.5004687657830311
#   warmup_time: 0.0029523372650146484
# (XGBoostTrainer pid=70865) 2022-07-18 21:04:47,906	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 3.52 seconds (1.29 pure XGBoost training time).
# (XGBoostTrainer pid=70866) 2022-07-18 21:04:47,851	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 3.46 seconds (1.24 pure XGBoost training time).
# Result for XGBoostTrainer_ea7f4_00001:
#   date: 2022-07-18_21-04-47
#   done: true
#   experiment_id: 5f8025068bcb4ed4ac66cbc01b1c4265
#   experiment_tag: 1_max_depth=5
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 70865
#   should_checkpoint: true
#   time_since_restore: 3.583259105682373
#   time_this_iter_s: 0.06814098358154297
#   time_total_s: 3.583259105682373
#   timestamp: 1658203487
#   timesteps_since_restore: 0
#   train-error: 0.0
#   train-logloss: 0.01841634292981527
#   training_iteration: 20
#   trial_id: ea7f4_00001
#   valid-error: 0.05263157894736842
#   valid-logloss: 0.10578184703239703
#   warmup_time: 0.0031299591064453125
#
# Result for XGBoostTrainer_ea7f4_00002:
#   date: 2022-07-18_21-04-47
#   done: true
#   experiment_id: 45c11517546e48fba5953b3460d0119a
#   experiment_tag: 2_max_depth=3
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 70866
#   should_checkpoint: true
#   time_since_restore: 3.527599811553955
#   time_this_iter_s: 0.012126922607421875
#   time_total_s: 3.527599811553955
#   timestamp: 1658203487
#   timesteps_since_restore: 0
#   train-error: 0.0
#   train-logloss: 0.02151511543566108
#   training_iteration: 20
#   trial_id: ea7f4_00002
#   valid-error: 0.03508771929824561
#   valid-logloss: 0.07659151291540056
#   warmup_time: 0.0029523372650146484
# (XGBoostTrainer pid=70942) 2022-07-18 21:04:48,884	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# (XGBoostTrainer pid=70953) 2022-07-18 21:04:49,877	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# (XGBoostTrainer pid=70942) 2022-07-18 21:04:50,605	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (XGBoostTrainer pid=70953) 2022-07-18 21:04:50,758	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (_RemoteRayXGBoostActor pid=70976) 2022-07-18 21:04:51,785	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=70976)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=70976)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=70976)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=70976)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=70976)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=70976)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=70976)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=70976)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=70976)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=70976)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=70976)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=70976)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=70976)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=70976)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=70976)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=70976)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=70977) 2022-07-18 21:04:51,785	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=70977)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=70977)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=70977)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=70977)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=70977)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=70977)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=70977)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=70977)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=70977)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=70977)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=70977)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=70977)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=70977)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=70977)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=70977)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=70977)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=70987) 2022-07-18 21:04:51,931	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=70987)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=70987)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=70987)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=70987)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=70987)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=70987)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=70987)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=70987)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=70987)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=70987)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=70987)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=70987)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=70987)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=70987)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=70987)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=70987)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=70986) 2022-07-18 21:04:51,931	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=70986)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=70986)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=70986)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=70986)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=70986)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=70986)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=70986)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=70986)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=70986)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=70986)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=70986)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=70986)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=70986)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=70986)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=70986)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=70986)     traceback.print_stack()
# (XGBoostTrainer pid=70942) 2022-07-18 21:04:52,750	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (_RemoteRayXGBoostActor pid=70976) [21:04:52] task [xgboost.ray]:4957281392 got new rank 0
# (_RemoteRayXGBoostActor pid=70977) [21:04:52] task [xgboost.ray]:4987428000 got new rank 1
# (XGBoostTrainer pid=70953) 2022-07-18 21:04:52,897	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (_RemoteRayXGBoostActor pid=70987) [21:04:52] task [xgboost.ray]:5008104656 got new rank 1
# (_RemoteRayXGBoostActor pid=70986) [21:04:52] task [xgboost.ray]:4829027392 got new rank 0
# Result for XGBoostTrainer_ea7f4_00003:
#   date: 2022-07-18_21-04-53
#   done: false
#   experiment_id: 19226b5824c84cd39c0ee7b613d47917
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 70942
#   should_checkpoint: true
#   time_since_restore: 4.885594844818115
#   time_this_iter_s: 4.885594844818115
#   time_total_s: 4.885594844818115
#   timestamp: 1658203493
#   timesteps_since_restore: 0
#   train-error: 0.07537688442211055
#   train-logloss: 0.5118698591562971
#   training_iteration: 1
#   trial_id: ea7f4_00003
#   valid-error: 0.0935672514619883
#   valid-logloss: 0.5195214661241275
#   warmup_time: 0.0029630661010742188
#
# Result for XGBoostTrainer_ea7f4_00004:
#   date: 2022-07-18_21-04-53
#   done: false
#   experiment_id: 3026cf2a23684e0183bbced308281d66
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 70953
#   should_checkpoint: true
#   time_since_restore: 4.043035984039307
#   time_this_iter_s: 4.043035984039307
#   time_total_s: 4.043035984039307
#   timestamp: 1658203493
#   timesteps_since_restore: 0
#   train-error: 0.02261306532663317
#   train-logloss: 0.464117960489575
#   training_iteration: 1
#   trial_id: ea7f4_00004
#   valid-error: 0.11695906432748537
#   valid-logloss: 0.5025240946234318
#   warmup_time: 0.002991199493408203
# (XGBoostTrainer pid=70942) 2022-07-18 21:04:54,161	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 3.57 seconds (1.41 pure XGBoost training time).
# Result for XGBoostTrainer_ea7f4_00003:
#   date: 2022-07-18_21-04-54
#   done: true
#   experiment_id: 19226b5824c84cd39c0ee7b613d47917
#   experiment_tag: 3_max_depth=1
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 70942
#   should_checkpoint: true
#   time_since_restore: 5.2710089683532715
#   time_this_iter_s: 0.007917165756225586
#   time_total_s: 5.2710089683532715
#   timestamp: 1658203494
#   timesteps_since_restore: 0
#   train-error: 0.01758793969849246
#   train-logloss: 0.09552153718105551
#   training_iteration: 20
#   trial_id: ea7f4_00003
#   valid-error: 0.02923976608187134
#   valid-logloss: 0.11200698223564098
#   warmup_time: 0.0029630661010742188
#
# Result for XGBoostTrainer_ea7f4_00004:
#   date: 2022-07-18_21-04-54
#   done: true
#   experiment_id: 3026cf2a23684e0183bbced308281d66
#   experiment_tag: 4_max_depth=6
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 70953
#   should_checkpoint: true
#   time_since_restore: 4.482537031173706
#   time_this_iter_s: 0.007193803787231445
#   time_total_s: 4.482537031173706
#   timestamp: 1658203494
#   timesteps_since_restore: 0
#   train-error: 0.0
#   train-logloss: 0.01849572773292735
#   training_iteration: 20
#   trial_id: ea7f4_00004
#   valid-error: 0.04093567251461988
#   valid-logloss: 0.08938791319913073
#   warmup_time: 0.002991199493408203
# (XGBoostTrainer pid=70953) 2022-07-18 21:04:54,365	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 3.62 seconds (1.46 pure XGBoost training time).
# Best Result: Result(metrics={'train-logloss': 0.01841634292981527, 'train-error': 0.0, 'valid-logloss': 0.10578184703239703, 'valid-error': 0.05263157894736842, 'time_this_iter_s': 0.06814098358154297, 'should_checkpoint': True, 'done': True, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 20, 'trial_id': 'ea7f4_00001', 'experiment_id': '5f8025068bcb4ed4ac66cbc01b1c4265', 'date': '2022-07-18_21-04-47', 'timestamp': 1658203487, 'time_total_s': 3.583259105682373, 'pid': 70865, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_restore': 3.583259105682373, 'timesteps_since_restore': 0, 'iterations_since_restore': 20, 'warmup_time': 0.0031299591064453125, 'experiment_tag': '1_max_depth=5'}, checkpoint=<ray.air.checkpoint.Checkpoint object at 0x15eb14bb0>, error=None, log_dir=PosixPath('/Users/jules/ray_results/XGBoostTrainer_2022-07-18_21-04-41/XGBoostTrainer_ea7f4_00001_1_max_depth=5_2022-07-18_21-04-43'), metrics_dataframe=    train-logloss  train-error  valid-logloss  valid-error  time_this_iter_s  \
# 0        0.465611     0.022613       0.505882     0.093567          3.318230
# 1        0.332896     0.010050       0.386077     0.052632          0.017062
# 2        0.252007     0.012563       0.326293     0.076023          0.010697
# 3        0.191715     0.010050       0.267602     0.058480          0.010144
# 4        0.149730     0.007538       0.226837     0.052632          0.010337
# 5        0.119332     0.007538       0.198947     0.046784          0.010524
# 6        0.096740     0.005025       0.175565     0.052632          0.010143
# 7        0.078592     0.002513       0.163899     0.052632          0.014277
# 8        0.065687     0.002513       0.155128     0.052632          0.011135
# 9        0.055314     0.002513       0.146913     0.052632          0.012306
# 10       0.047350     0.002513       0.136977     0.052632          0.010709
# 11       0.041698     0.002513       0.133636     0.052632          0.010569
# 12       0.036109     0.002513       0.124063     0.052632          0.009637
# 13       0.032127     0.002513       0.120173     0.052632          0.010114
# 14       0.028889     0.002513       0.116081     0.058480          0.010461
# 15       0.026126     0.000000       0.111825     0.052632          0.007902
# 16       0.023875     0.000000       0.114316     0.058480          0.010226
# 17       0.021785     0.000000       0.112586     0.052632          0.009519
# 18       0.019855     0.000000       0.107597     0.052632          0.011126
# 19       0.018416     0.000000       0.105782     0.052632          0.068141
#
#     should_checkpoint   done  timesteps_total  episodes_total  \
# 0                True  False              NaN             NaN
# 1                True  False              NaN             NaN
# 2                True  False              NaN             NaN
# 3                True  False              NaN             NaN
# 4                True  False              NaN             NaN
# 5                True  False              NaN             NaN
# 6                True  False              NaN             NaN
# 7                True  False              NaN             NaN
# 8                True  False              NaN             NaN
# 9                True  False              NaN             NaN
# 10               True  False              NaN             NaN
# 11               True  False              NaN             NaN
# 12               True  False              NaN             NaN
# 13               True  False              NaN             NaN
# 14               True  False              NaN             NaN
# 15               True  False              NaN             NaN
# 16               True  False              NaN             NaN
# 17               True  False              NaN             NaN
# 18               True  False              NaN             NaN
# 19               True  False              NaN             NaN
#
#     training_iteration  ...                 date   timestamp time_total_s  \
# 0                    1  ...  2022-07-18_21-04-47  1658203487     3.318230
# 1                    2  ...  2022-07-18_21-04-47  1658203487     3.335292
# 2                    3  ...  2022-07-18_21-04-47  1658203487     3.345989
# 3                    4  ...  2022-07-18_21-04-47  1658203487     3.356133
# 4                    5  ...  2022-07-18_21-04-47  1658203487     3.366470
# 5                    6  ...  2022-07-18_21-04-47  1658203487     3.376994
# 6                    7  ...  2022-07-18_21-04-47  1658203487     3.387137
# 7                    8  ...  2022-07-18_21-04-47  1658203487     3.401414
# 8                    9  ...  2022-07-18_21-04-47  1658203487     3.412549
# 9                   10  ...  2022-07-18_21-04-47  1658203487     3.424855
# 10                  11  ...  2022-07-18_21-04-47  1658203487     3.435564
# 11                  12  ...  2022-07-18_21-04-47  1658203487     3.446133
# 12                  13  ...  2022-07-18_21-04-47  1658203487     3.455770
# 13                  14  ...  2022-07-18_21-04-47  1658203487     3.465884
# 14                  15  ...  2022-07-18_21-04-47  1658203487     3.476345
# 15                  16  ...  2022-07-18_21-04-47  1658203487     3.484247
# 16                  17  ...  2022-07-18_21-04-47  1658203487     3.494473
# 17                  18  ...  2022-07-18_21-04-47  1658203487     3.503992
# 18                  19  ...  2022-07-18_21-04-47  1658203487     3.515118
# 19                  20  ...  2022-07-18_21-04-47  1658203487     3.583259
#
#       pid               hostname    node_ip time_since_restore  \
# 0   70865  Juless-MacBook-Pro-16  127.0.0.1           3.318230
# 1   70865  Juless-MacBook-Pro-16  127.0.0.1           3.335292
# 2   70865  Juless-MacBook-Pro-16  127.0.0.1           3.345989
# 3   70865  Juless-MacBook-Pro-16  127.0.0.1           3.356133
# 4   70865  Juless-MacBook-Pro-16  127.0.0.1           3.366470
# 5   70865  Juless-MacBook-Pro-16  127.0.0.1           3.376994
# 6   70865  Juless-MacBook-Pro-16  127.0.0.1           3.387137
# 7   70865  Juless-MacBook-Pro-16  127.0.0.1           3.401414
# 8   70865  Juless-MacBook-Pro-16  127.0.0.1           3.412549
# 9   70865  Juless-MacBook-Pro-16  127.0.0.1           3.424855
# 10  70865  Juless-MacBook-Pro-16  127.0.0.1           3.435564
# 11  70865  Juless-MacBook-Pro-16  127.0.0.1           3.446133
# 12  70865  Juless-MacBook-Pro-16  127.0.0.1           3.455770
# 13  70865  Juless-MacBook-Pro-16  127.0.0.1           3.465884
# 14  70865  Juless-MacBook-Pro-16  127.0.0.1           3.476345
# 15  70865  Juless-MacBook-Pro-16  127.0.0.1           3.484247
# 16  70865  Juless-MacBook-Pro-16  127.0.0.1           3.494473
# 17  70865  Juless-MacBook-Pro-16  127.0.0.1           3.503992
# 18  70865  Juless-MacBook-Pro-16  127.0.0.1           3.515118
# 19  70865  Juless-MacBook-Pro-16  127.0.0.1           3.583259
#
#    timesteps_since_restore  iterations_since_restore  warmup_time
# 0                        0                         1      0.00313
# 1                        0                         2      0.00313
# 2                        0                         3      0.00313
# 3                        0                         4      0.00313
# 4                        0                         5      0.00313
# 5                        0                         6      0.00313
# 6                        0                         7      0.00313
# 7                        0                         8      0.00313
# 8                        0                         9      0.00313
# 9                        0                        10      0.00313
# 10                       0                        11      0.00313
# 11                       0                        12      0.00313
# 12                       0                        13      0.00313
# 13                       0                        14      0.00313
# 14                       0                        15      0.00313
# 15                       0                        16      0.00313
# 16                       0                        17      0.00313
# 17                       0                        18      0.00313
# 18                       0                        19      0.00313
# 19                       0                        20      0.00313
#
# [20 rows x 22 columns], best_checkpoints=[(<ray.air.checkpoint.Checkpoint object at 0x15eb1d250>, {'train-logloss': 0.465611254524945, 'train-error': 0.02261306532663317, 'valid-logloss': 0.5058815336366843, 'valid-error': 0.0935672514619883, 'time_this_iter_s': 3.318230152130127, 'should_checkpoint': True, 'done': False, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 1, 'trial_id': 'ea7f4_00001', 'experiment_id': '5f8025068bcb4ed4ac66cbc01b1c4265', 'date': '2022-07-18_21-04-47', 'timestamp': 1658203487, 'time_total_s': 3.318230152130127, 'pid': 70865, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_restore': 3.318230152130127, 'timesteps_since_restore': 0, 'iterations_since_restore': 1, 'warmup_time': 0.0031299591064453125, 'experiment_tag': '1_max_depth=5'}), (<ray.air.checkpoint.Checkpoint object at 0x15eb1d550>, {'train-logloss': 0.33289550244808197, 'train-error': 0.01005025125628141, 'valid-logloss': 0.3860774944748795, 'valid-error': 0.05263157894736842, 'time_this_iter_s': 0.017061948776245117, 'should_checkpoint': True, 'done': False, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 2, 'trial_id': 'ea7f4_00001', 'experiment_id': '5f8025068bcb4ed4ac66cbc01b1c4265', 'date': '2022-07-18_21-04-47', 'timestamp': 1658203487, 'time_total_s': 3.335292100906372, 'pid': 70865, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_restore': 3.335292100906372, 'timesteps_since_restore': 0, 'iterations_since_restore': 2, 'warmup_time': 0.0031299591064453125, 'experiment_tag': '1_max_depth=5'}), (<ray.air.checkpoint.Checkpoint object at 0x15eb1d610>, {'train-logloss': 0.2520069157583031, 'train-error': 0.01256281407035176, 'valid-logloss': 0.3262928800973279, 'valid-error': 0.07602339181286549, 'time_this_iter_s': 0.010697126388549805, 'should_checkpoint': True, 'done': False, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 3, 'trial_id': 'ea7f4_00001', 'experiment_id': '5f8025068bcb4ed4ac66cbc01b1c4265', 'date': '2022-07-18_21-04-47', 'timestamp': 1658203487, 'time_total_s': 3.345989227294922, 'pid': 70865, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_restore': 3.345989227294922, 'timesteps_since_restore': 0, 'iterations_since_restore': 3, 'warmup_time': 0.0031299591064453125, 'experiment_tag': '1_max_depth=5'}), (<ray.air.checkpoint.Checkpoint object at 0x16a5981c0>, {'train-logloss': 0.19171511336936423, 'train-error': 0.01005025125628141, 'valid-logloss': 0.26760199273887436, 'valid-error': 0.05847953216374269, 'time_this_iter_s': 0.01014399528503418, 'should_checkpoint': True, 'done': False, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 4, 'trial_id': 'ea7f4_00001', 'experiment_id': '5f8025068bcb4ed4ac66cbc01b1c4265', 'date': '2022-07-18_21-04-47', 'timestamp': 1658203487, 'time_total_s': 3.356133222579956, 'pid': 70865, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_restore': 3.356133222579956, 'timesteps_since_restore': 0, 'iterations_since_restore': 4, 'warmup_time': 0.0031299591064453125, 'experiment_tag': '1_max_depth=5'}), (<ray.air.checkpoint.Checkpoint object at 0x16a598fd0>, {'train-logloss': 0.14972986310870204, 'train-error': 0.00753768844221105, 'valid-logloss': 0.22683743971307374, 'valid-error': 0.05263157894736842, 'time_this_iter_s': 0.010336875915527344, 'should_checkpoint': True, 'done': False, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 5, 'trial_id': 'ea7f4_00001', 'experiment_id': '5f8025068bcb4ed4ac66cbc01b1c4265', 'date': '2022-07-18_21-04-47', 'timestamp': 1658203487, 'time_total_s': 3.3664700984954834, 'pid': 70865, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_res ...

# %% [markdown]
# ### Create a `BatchPreditor` for batch prediction
# Load the model from the checkpoint

# %%
from ray.train.batch_predictor import BatchPredictor
from ray.train.xgboost import XGBoostPredictor

batch_predictor = BatchPredictor.from_checkpoint(result.checkpoint, XGBoostPredictor)

predicted_probabilities = batch_predictor.predict(test_dataset)
print("PREDICTED PROBABILITIES")
predicted_probabilities.show()
# Out:
# Map Progress (1 actors 1 pending): 100%|█████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.29it/s]
# PREDICTED PROBABILITIES
# {'predictions': 0.9964648485183716}
# {'predictions': 0.9951295852661133}
# {'predictions': 0.0037899704184383154}
# {'predictions': 0.9964648485183716}
# {'predictions': 0.9969868063926697}
# {'predictions': 0.9947494864463806}
# {'predictions': 0.9899886250495911}
# {'predictions': 0.9952162504196167}
# {'predictions': 0.3375702202320099}
# {'predictions': 0.9766711592674255}
# {'predictions': 0.0037899704184383154}
# {'predictions': 0.9948934316635132}
# {'predictions': 0.9472665786743164}
# {'predictions': 0.989780068397522}
# {'predictions': 0.9952002763748169}
# {'predictions': 0.18953870236873627}
# {'predictions': 0.2149435132741928}
# {'predictions': 0.99428790807724}
# {'predictions': 0.9890844225883484}
# {'predictions': 0.0037899704184383154}

# %% [markdown]
# ### Create `PredictorDeployment` for Online Inference
# Deploy the model as an inference service by using Ray Serve and the `PredictorDeployment` class.

# %%
from ray import serve
from fastapi import Request
from ray.serve import PredictorDeployment
from ray.serve.http_adapters import json_request


async def adapter(request: Request):
    content = await request.json()
    print(content)
    return pd.DataFrame.from_dict(content)


serve.start(detached=True)
deployment = PredictorDeployment.options(name="XGBoostService")

deployment.deploy(
    XGBoostPredictor, result.checkpoint, batching_params=False, http_adapter=adapter
)

print(deployment.url)
# Out:
# (ServeController pid=71210) INFO 2022-07-18 21:06:20,059 controller 71210 checkpoint_path.py:17 - Using RayInternalKVStore for controller checkpoint and recovery.
# (ServeController pid=71210) INFO 2022-07-18 21:06:20,081 controller 71210 http_state.py:123 - Starting HTTP proxy with name 'SERVE_CONTROLLER_ACTOR:SERVE_PROXY_ACTOR-4a225d65b457a9b0566e99c1b6d70ca6e0f6f369fb83c01166d68deb' on node '4a225d65b457a9b0566e99c1b6d70ca6e0f6f369fb83c01166d68deb' listening on '127.0.0.1:8000'
# (HTTPProxyActor pid=71212) INFO:     Started server process [71212]
# (ServeController pid=71210) INFO 2022-07-18 21:06:20,804 controller 71210 deployment_state.py:1280 - Adding 1 replicas to deployment 'XGBoostService'.
# http://127.0.0.1:8000/XGBoostService

# %% [markdown]
# After deploying the service, you can send requests to it.

# %%
import requests

sample_input = test_dataset.take(1)
sample_input = dict(sample_input[0])

output = requests.post(deployment.url, json=[sample_input]).json()
print(output)

# %%
ray.shutdown()

# %% [markdown]
# ### Homework
#
# 1. Have a go at Ray AIR examples in the documentation.
