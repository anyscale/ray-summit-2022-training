# %% [markdown]
# ## A gentle 10-minute introduction to Ray AI Runitime (Ray AIR)
#
# As part of Ray 2.0, Ray AI Runtime (AIR) is an open-source toolkit for building end-to-end ML applications. By leveraging Ray, its distributed compute capabilities, and its library ecosystem, Ray AIR brings scalability and programmability to ML platforms.
#
# Ray AI Runtime focuses on two functional aspects:
#  * It provides scalability by leveraging Ray’s distributed compute layer for ML workloads.
#  * It is designed to interoperate with other systems for storage and metadata needs.
#
# Ray AIR consists of five key components:
#
#  * Data processing (Ray Data)
#  * Model Training (Ray Train)
#  * Reinforcement Learning (Ray RLlib)
#  * Hyperparameter Tuning (Ray Tune)
#  * Model Serving (Ray Serve).
#
#  <img src = "images/ai_runtime.jpeg" width="60%" height="30%">
#
# ### Learning objectives:
#   * Get introduced to Ray AIR as a unified toolkit to write an end-to-end ML application in a single Python script
#   * Get exposed to Ray data for data ingestion
#   * Use out-of-box Preprocessors
#   * Load model from the best model checkpoint and use for batch inference
#   * Deploy best checkpoint model and use for online inference

# %%
import logging, os, random, warnings
from pprint import pprint
import ray
import pandas as pd
from sklearn.model_selection import train_test_split

from ray.data.preprocessors import StandardScaler

# %%
warnings.filterwarnings("ignore")
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
if ray.is_initialized:
    ray.shutdown()
context = ray.init(logging_level=logging.ERROR)
pprint(context)
# Out:
# RayContext(dashboard_url='127.0.0.1:8266', python_version='3.8.13', ray_version='3.0.0.dev0', ray_commit='{{RAY_COMMIT_SHA}}', address_info={'node_ip_address': '127.0.0.1', 'raylet_ip_address': '127.0.0.1', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2022-07-20_10-50-36_525779_37136/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-07-20_10-50-36_525779_37136/sockets/raylet', 'webui_url': '127.0.0.1:8266', 'session_dir': '/tmp/ray/session_2022-07-20_10-50-36_525779_37136', 'metrics_export_port': 60313, 'gcs_address': '127.0.0.1:60825', 'address': '127.0.0.1:60825', 'dashboard_agent_listen_port': 52365, 'node_id': '9636fa263e340aa24cb609b086fee61a841cb0258492f120360b1dc5'})

# %%
print(f"Dashboard url: http://{context.address_info['webui_url']}")
# Out:
# Dashboard url: http://127.0.0.1:8266

# %% [markdown]
# ### Create Ray data from an S3 CSV datasource

# %%
import ray
import pandas as pd
from ray.air import train_test_split

# Split data into train and validation.
dataset = ray.data.read_csv("s3://anonymous@air-example-data/breast_cancer.csv")
train_dataset, valid_dataset = train_test_split(dataset, test_size=0.3)
test_dataset = valid_dataset.drop_columns(["target"])
# Out:
# Map_Batches: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 85.41it/s]

# %% [markdown]
# ### Create Preprocessors
# This preprocessor is automatically used in the training function to `fit` and `tranform` your datasets for training and validation.

# %%
# Create a preprocessor to scale some columns
from ray.data.preprocessors import StandardScaler

columns_to_scale = ["mean radius", "mean texture"]
preprocessor = StandardScaler(columns=columns_to_scale)

# %% [markdown]
# ### Create Trainers
# Use the Ray AIR trainer `XGBoostTrainer`. Simple steps:
#  1. define the parallelism for Ray compute
#  2. define the XGBoost parameters for training
#  3. supply the preprocessor for fitting and transforming dataset during training and validation
#  4. provide the datasets training and validation
#  5. invoke `trainer.fit()`
#
#  Simple API that does a lot behind the scenes!

# %%
from ray.train.xgboost import XGBoostTrainer

trainer = XGBoostTrainer(
    scaling_config={
        # Number of workers to use for data parallelism.
        "num_workers": 2,
        # Whether to use GPU acceleration.
        "use_gpu": False,
    },
    label_column="target",
    num_boost_round=20,
    params={
        # XGBoost specific params
        "objective": "binary:logistic",
        "eval_metric": ["logloss", "error"],
    },
    datasets={"train": train_dataset, "valid": valid_dataset},
    preprocessor=preprocessor,
)
result = trainer.fit()
print(result.metrics)
# Out:
# == Status ==<br>Current time: 2022-07-20 10:51:07 (running for 00:00:06.45)<br>Memory usage on this node: 16.8/64.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/10 CPUs, 0/0 GPUs, 0.0/43.98 GiB heap, 0.0/2.0 GiB objects<br>Result logdir: /Users/jules/ray_results/XGBoostTrainer_2022-07-20_10-51-00<br>Number of trials: 1/1 (1 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                </th><th>status    </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train-logloss</th><th style="text-align: right;">  train-error</th><th style="text-align: right;">  valid-logloss</th></tr>
# </thead>
# <tbody>
# <tr><td>XGBoostTrainer_8445e_00000</td><td>TERMINATED</td><td>127.0.0.1:37705</td><td style="text-align: right;">    20</td><td style="text-align: right;">         4.69404</td><td style="text-align: right;">      0.0184957</td><td style="text-align: right;">            0</td><td style="text-align: right;">      0.0893879</td></tr>
# </tbody>
# </table><br><br>
# (XGBoostTrainer pid=37705) 2022-07-20 10:51:02,193	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# (XGBoostTrainer pid=37705) 2022-07-20 10:51:03,762	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (_RemoteRayXGBoostActor pid=37720) 2022-07-20 10:51:04,845	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=37720)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=37720)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=37720)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=37720)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=37720)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=37720)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=37720)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=37720)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=37720)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=37720)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=37720)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=37720)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=37720)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=37720)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=37720)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=37720)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=37719) 2022-07-20 10:51:04,845	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=37719)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=37719)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=37719)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=37719)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=37719)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=37719)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=37719)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=37719)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=37719)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=37719)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=37719)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=37719)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=37719)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=37719)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=37719)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=37719)     traceback.print_stack()
# (XGBoostTrainer pid=37705) 2022-07-20 10:51:04,960	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (_RemoteRayXGBoostActor pid=37720) [10:51:04] task [xgboost.ray]:4979829920 got new rank 1
# (_RemoteRayXGBoostActor pid=37719) [10:51:04] task [xgboost.ray]:5518236880 got new rank 0
# Result for XGBoostTrainer_8445e_00000:
#   date: 2022-07-20_10-51-06
#   done: false
#   experiment_id: 7f1aab7f31e442649ffb9a5be3333897
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 37705
#   should_checkpoint: true
#   time_since_restore: 4.478966951370239
#   time_this_iter_s: 4.478966951370239
#   time_total_s: 4.478966951370239
#   timestamp: 1658339466
#   timesteps_since_restore: 0
#   train-error: 0.02261306532663317
#   train-logloss: 0.464117960489575
#   training_iteration: 1
#   trial_id: 8445e_00000
#   valid-error: 0.11695906432748537
#   valid-logloss: 0.5025240946234318
#   warmup_time: 0.0026171207427978516
# (XGBoostTrainer pid=37705) 2022-07-20 10:51:06,893	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 3.14 seconds (1.93 pure XGBoost training time).
# Result for XGBoostTrainer_8445e_00000:
#   date: 2022-07-20_10-51-06
#   done: true
#   experiment_id: 7f1aab7f31e442649ffb9a5be3333897
#   experiment_tag: '0'
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 37705
#   should_checkpoint: true
#   time_since_restore: 4.694040060043335
#   time_this_iter_s: 0.006032228469848633
#   time_total_s: 4.694040060043335
#   timestamp: 1658339466
#   timesteps_since_restore: 0
#   train-error: 0.0
#   train-logloss: 0.01849572773292735
#   training_iteration: 20
#   trial_id: 8445e_00000
#   valid-error: 0.04093567251461988
#   valid-logloss: 0.08938791319913073
#   warmup_time: 0.0026171207427978516
#
# {'train-logloss': 0.01849572773292735, 'train-error': 0.0, 'valid-logloss': 0.08938791319913073, 'valid-error': 0.04093567251461988, 'time_this_iter_s': 0.006032228469848633, 'should_checkpoint': True, 'done': True, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 20, 'trial_id': '8445e_00000', 'experiment_id': '7f1aab7f31e442649ffb9a5be3333897', 'date': '2022-07-20_10-51-06', 'timestamp': 1658339466, 'time_total_s': 4.694040060043335, 'pid': 37705, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {}, 'time_since_restore': 4.694040060043335, 'timesteps_since_restore': 0, 'iterations_since_restore': 20, 'warmup_time': 0.0026171207427978516, 'experiment_tag': '0'}

# %% [markdown]
# ### Create Tuner for hyperparameter search
#
# What if you want to do hyperparameter optimization during training and use the best config for the model?
# Well, you can then use Tuner and supply your training function, Trainer, as part of the argument, along with other Tuner
# configuration.
#
# Again, simple steps:
#  1. define your hyperparameter space
#  2. define `TuneConfig` for number of trials and parallelism
#  3. invoke `tuner.fit()`

# %%
from ray import tune

param_space = {"params": {"max_depth": tune.randint(1, 9)}}
metric = "train-logloss"

# %%
from ray.tune.tuner import Tuner, TuneConfig
from ray.air.config import RunConfig

tuner = Tuner(
    trainer,
    param_space=param_space,
    tune_config=TuneConfig(num_samples=5, metric=metric, mode="min"),
)
# Execute tuning.
result_grid = tuner.fit()

# Fetch the best result with its best hyperparameter config 
best_result = result_grid.get_best_result()
print("Best Result:", best_result)
# Out:
# == Status ==<br>Current time: 2022-07-20 10:51:27 (running for 00:00:12.68)<br>Memory usage on this node: 16.1/64.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/10 CPUs, 0/0 GPUs, 0.0/43.98 GiB heap, 0.0/2.0 GiB objects<br>Current best trial: 8c9fe_00003 with train-logloss=0.01841634292981527 and parameters={'params': {'max_depth': 5}}<br>Result logdir: /Users/jules/ray_results/XGBoostTrainer_2022-07-20_10-51-14<br>Number of trials: 5/5 (5 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                </th><th>status    </th><th>loc            </th><th style="text-align: right;">  params/max_depth</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train-logloss</th><th style="text-align: right;">  train-error</th><th style="text-align: right;">  valid-logloss</th></tr>
# </thead>
# <tbody>
# <tr><td>XGBoostTrainer_8c9fe_00000</td><td>TERMINATED</td><td>127.0.0.1:37732</td><td style="text-align: right;">                 6</td><td style="text-align: right;">    20</td><td style="text-align: right;">         2.59019</td><td style="text-align: right;">      0.0184957</td><td style="text-align: right;">            0</td><td style="text-align: right;">      0.0893879</td></tr>
# <tr><td>XGBoostTrainer_8c9fe_00001</td><td>TERMINATED</td><td>127.0.0.1:37735</td><td style="text-align: right;">                 3</td><td style="text-align: right;">    20</td><td style="text-align: right;">         4.71449</td><td style="text-align: right;">      0.0215151</td><td style="text-align: right;">            0</td><td style="text-align: right;">      0.0765915</td></tr>
# <tr><td>XGBoostTrainer_8c9fe_00002</td><td>TERMINATED</td><td>127.0.0.1:37736</td><td style="text-align: right;">                 6</td><td style="text-align: right;">    20</td><td style="text-align: right;">         4.71488</td><td style="text-align: right;">      0.0184957</td><td style="text-align: right;">            0</td><td style="text-align: right;">      0.0893879</td></tr>
# <tr><td>XGBoostTrainer_8c9fe_00003</td><td>TERMINATED</td><td>127.0.0.1:37797</td><td style="text-align: right;">                 5</td><td style="text-align: right;">    20</td><td style="text-align: right;">         4.82036</td><td style="text-align: right;">      0.0184163</td><td style="text-align: right;">            0</td><td style="text-align: right;">      0.105782 </td></tr>
# <tr><td>XGBoostTrainer_8c9fe_00004</td><td>TERMINATED</td><td>127.0.0.1:37807</td><td style="text-align: right;">                 3</td><td style="text-align: right;">    20</td><td style="text-align: right;">         3.04534</td><td style="text-align: right;">      0.0215151</td><td style="text-align: right;">            0</td><td style="text-align: right;">      0.0765915</td></tr>
# </tbody>
# </table><br><br>
# (XGBoostTrainer pid=37732) 2022-07-20 10:51:16,014	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# (XGBoostTrainer pid=37732) 2022-07-20 10:51:16,144	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (XGBoostTrainer pid=37736) 2022-07-20 10:51:17,188	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# (XGBoostTrainer pid=37736) 2022-07-20 10:51:17,261	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (XGBoostTrainer pid=37735) 2022-07-20 10:51:17,188	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# (XGBoostTrainer pid=37735) 2022-07-20 10:51:17,266	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (_RemoteRayXGBoostActor pid=37742) 2022-07-20 10:51:17,180	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=37742)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=37742)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=37742)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=37742)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=37742)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=37742)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=37742)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=37742)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=37742)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=37742)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=37742)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=37742)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=37742)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=37742)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=37742)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=37742)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=37741) 2022-07-20 10:51:17,176	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=37741)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=37741)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=37741)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=37741)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=37741)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=37741)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=37741)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=37741)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=37741)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=37741)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=37741)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=37741)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=37741)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=37741)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=37741)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=37741)     traceback.print_stack()
# (XGBoostTrainer pid=37732) 2022-07-20 10:51:17,294	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (_RemoteRayXGBoostActor pid=37742) [10:51:17] task [xgboost.ray]:4966988960 got new rank 1
# (_RemoteRayXGBoostActor pid=37741) [10:51:17] task [xgboost.ray]:5663439936 got new rank 0
# Result for XGBoostTrainer_8c9fe_00000:
#   date: 2022-07-20_10-51-18
#   done: false
#   experiment_id: ea59ac27b07a45e6a95ca69f0922911b
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 37732
#   should_checkpoint: true
#   time_since_restore: 2.3179068565368652
#   time_this_iter_s: 2.3179068565368652
#   time_total_s: 2.3179068565368652
#   timestamp: 1658339478
#   timesteps_since_restore: 0
#   train-error: 0.02261306532663317
#   train-logloss: 0.464117960489575
#   training_iteration: 1
#   trial_id: 8c9fe_00000
#   valid-error: 0.11695906432748537
#   valid-logloss: 0.5025240946234318
#   warmup_time: 0.002615213394165039
# (_RemoteRayXGBoostActor pid=37758) 2022-07-20 10:51:18,462	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=37758)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=37758)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=37758)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=37758)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=37758)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=37758)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=37758)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=37758)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=37758)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=37758)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=37758)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=37758)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=37758)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=37758)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=37758)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=37758)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=37759) 2022-07-20 10:51:18,469	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=37759)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=37759)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=37759)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=37759)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=37759)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=37759)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=37759)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=37759)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=37759)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=37759)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=37759)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=37759)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=37759)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=37759)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=37759)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=37759)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=37756) 2022-07-20 10:51:18,474	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=37756)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=37756)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=37756)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=37756)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=37756)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=37756)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=37756)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=37756)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=37756)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=37756)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=37756)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=37756)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=37756)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=37756)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=37756)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=37756)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=37760) 2022-07-20 10:51:18,469	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=37760)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=37760)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=37760)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=37760)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=37760)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=37760)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=37760)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=37760)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=37760)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=37760)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=37760)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=37760)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=37760)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=37760)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=37760)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=37760)     traceback.print_stack()
# (XGBoostTrainer pid=37732) 2022-07-20 10:51:18,610	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 2.48 seconds (1.31 pure XGBoost training time).
# Result for XGBoostTrainer_8c9fe_00000:
#   date: 2022-07-20_10-51-18
#   done: true
#   experiment_id: ea59ac27b07a45e6a95ca69f0922911b
#   experiment_tag: 0_max_depth=6
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 37732
#   should_checkpoint: true
#   time_since_restore: 2.590191125869751
#   time_this_iter_s: 0.006448030471801758
#   time_total_s: 2.590191125869751
#   timestamp: 1658339478
#   timesteps_since_restore: 0
#   train-error: 0.0
#   train-logloss: 0.01849572773292735
#   training_iteration: 20
#   trial_id: 8c9fe_00000
#   valid-error: 0.04093567251461988
#   valid-logloss: 0.08938791319913073
#   warmup_time: 0.002615213394165039
# (XGBoostTrainer pid=37735) 2022-07-20 10:51:19,388	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (_RemoteRayXGBoostActor pid=37759) [10:51:19] task [xgboost.ray]:6064979008 got new rank 0
# (_RemoteRayXGBoostActor pid=37760) [10:51:19] task [xgboost.ray]:4972604528 got new rank 1
# (XGBoostTrainer pid=37736) 2022-07-20 10:51:19,758	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (_RemoteRayXGBoostActor pid=37758) [10:51:19] task [xgboost.ray]:4831173840 got new rank 1
# (_RemoteRayXGBoostActor pid=37756) [10:51:19] task [xgboost.ray]:4965248208 got new rank 0
# Result for XGBoostTrainer_8c9fe_00002:
#   date: 2022-07-20_10-51-21
#   done: false
#   experiment_id: b1f5186d36384d52b2e6eb616c547a53
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 37736
#   should_checkpoint: true
#   time_since_restore: 4.341001033782959
#   time_this_iter_s: 4.341001033782959
#   time_total_s: 4.341001033782959
#   timestamp: 1658339481
#   timesteps_since_restore: 0
#   train-error: 0.02261306532663317
#   train-logloss: 0.464117960489575
#   training_iteration: 1
#   trial_id: 8c9fe_00002
#   valid-error: 0.11695906432748537
#   valid-logloss: 0.5025240946234318
#   warmup_time: 0.002767801284790039
#
# Result for XGBoostTrainer_8c9fe_00001:
#   date: 2022-07-20_10-51-21
#   done: false
#   experiment_id: f1ab4dabcdc049e59ba5183347ffd239
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 37735
#   should_checkpoint: true
#   time_since_restore: 3.979931116104126
#   time_this_iter_s: 3.979931116104126
#   time_total_s: 3.979931116104126
#   timestamp: 1658339481
#   timesteps_since_restore: 0
#   train-error: 0.03517587939698492
#   train-logloss: 0.47431553248784053
#   training_iteration: 1
#   trial_id: 8c9fe_00001
#   valid-error: 0.09941520467836257
#   valid-logloss: 0.5004687657830311
#   warmup_time: 0.002496004104614258
# (XGBoostTrainer pid=37797) 2022-07-20 10:51:21,714	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# Result for XGBoostTrainer_8c9fe_00002:
#   date: 2022-07-20_10-51-21
#   done: true
#   experiment_id: b1f5186d36384d52b2e6eb616c547a53
#   experiment_tag: 2_max_depth=6
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 37736
#   should_checkpoint: true
#   time_since_restore: 4.714883089065552
#   time_this_iter_s: 0.010637044906616211
#   time_total_s: 4.714883089065552
#   timestamp: 1658339481
#   timesteps_since_restore: 0
#   train-error: 0.0
#   train-logloss: 0.01849572773292735
#   training_iteration: 20
#   trial_id: 8c9fe_00002
#   valid-error: 0.04093567251461988
#   valid-logloss: 0.08938791319913073
#   warmup_time: 0.002767801284790039
#
# Result for XGBoostTrainer_8c9fe_00001:
#   date: 2022-07-20_10-51-21
#   done: true
#   experiment_id: f1ab4dabcdc049e59ba5183347ffd239
#   experiment_tag: 1_max_depth=3
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 37735
#   should_checkpoint: true
#   time_since_restore: 4.714491128921509
#   time_this_iter_s: 0.009954214096069336
#   time_total_s: 4.714491128921509
#   timestamp: 1658339481
#   timesteps_since_restore: 0
#   train-error: 0.0
#   train-logloss: 0.02151511543566108
#   training_iteration: 20
#   trial_id: 8c9fe_00001
#   valid-error: 0.03508771929824561
#   valid-logloss: 0.07659151291540056
#   warmup_time: 0.002496004104614258
# (XGBoostTrainer pid=37736) 2022-07-20 10:51:21,911	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 4.66 seconds (2.15 pure XGBoost training time).
# (XGBoostTrainer pid=37735) 2022-07-20 10:51:21,910	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 4.66 seconds (2.52 pure XGBoost training time).
# (XGBoostTrainer pid=37797) 2022-07-20 10:51:23,378	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (XGBoostTrainer pid=37807) 2022-07-20 10:51:23,773	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# (XGBoostTrainer pid=37807) 2022-07-20 10:51:23,839	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (_RemoteRayXGBoostActor pid=37814) 2022-07-20 10:51:24,442	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=37814)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=37814)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=37814)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=37814)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=37814)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=37814)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=37814)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=37814)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=37814)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=37814)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=37814)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=37814)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=37814)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=37814)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=37814)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=37814)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=37815) 2022-07-20 10:51:24,442	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=37815)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=37815)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=37815)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=37815)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=37815)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=37815)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=37815)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=37815)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=37815)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=37815)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=37815)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=37815)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=37815)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=37815)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=37815)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=37815)     traceback.print_stack()
# (XGBoostTrainer pid=37797) 2022-07-20 10:51:24,557	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (_RemoteRayXGBoostActor pid=37814) [10:51:24] task [xgboost.ray]:5843230000 got new rank 0
# (_RemoteRayXGBoostActor pid=37815) [10:51:24] task [xgboost.ray]:5103545600 got new rank 1
# (_RemoteRayXGBoostActor pid=37827) 2022-07-20 10:51:24,902	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=37827)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=37827)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=37827)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=37827)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=37827)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=37827)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=37827)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=37827)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=37827)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=37827)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=37827)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=37827)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=37827)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=37827)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=37827)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=37827)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=37826) 2022-07-20 10:51:24,902	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=37826)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=37826)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=37826)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=37826)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=37826)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=37826)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=37826)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=37826)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=37826)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=37826)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=37826)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=37826)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=37826)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=37826)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=37826)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=37826)     traceback.print_stack()
# (XGBoostTrainer pid=37807) 2022-07-20 10:51:25,019	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (_RemoteRayXGBoostActor pid=37827) [10:51:25] task [xgboost.ray]:4817952000 got new rank 1
# (_RemoteRayXGBoostActor pid=37826) [10:51:25] task [xgboost.ray]:5157788880 got new rank 0
# Result for XGBoostTrainer_8c9fe_00003:
#   date: 2022-07-20_10-51-26
#   done: false
#   experiment_id: d4fe8d1c1b3143fcbbb72c60b7c3af14
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 37797
#   should_checkpoint: true
#   time_since_restore: 4.623799800872803
#   time_this_iter_s: 4.623799800872803
#   time_total_s: 4.623799800872803
#   timestamp: 1658339486
#   timesteps_since_restore: 0
#   train-error: 0.02261306532663317
#   train-logloss: 0.465611254524945
#   training_iteration: 1
#   trial_id: 8c9fe_00003
#   valid-error: 0.0935672514619883
#   valid-logloss: 0.5058815336366843
#   warmup_time: 0.0027060508728027344
# (XGBoostTrainer pid=37797) 2022-07-20 10:51:26,538	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 3.17 seconds (1.98 pure XGBoost training time).
# Result for XGBoostTrainer_8c9fe_00004:
#   date: 2022-07-20_10-51-26
#   done: false
#   experiment_id: 515f978fe4ab42639814cb09799a2311
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 37807
#   should_checkpoint: true
#   time_since_restore: 2.9219861030578613
#   time_this_iter_s: 2.9219861030578613
#   time_total_s: 2.9219861030578613
#   timestamp: 1658339486
#   timesteps_since_restore: 0
#   train-error: 0.03517587939698492
#   train-logloss: 0.47431553248784053
#   training_iteration: 1
#   trial_id: 8c9fe_00004
#   valid-error: 0.09941520467836257
#   valid-logloss: 0.5004687657830311
#   warmup_time: 0.002939939498901367
# (XGBoostTrainer pid=37807) 2022-07-20 10:51:26,823	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 3.00 seconds (1.80 pure XGBoost training time).
# Result for XGBoostTrainer_8c9fe_00003:
#   date: 2022-07-20_10-51-26
#   done: true
#   experiment_id: d4fe8d1c1b3143fcbbb72c60b7c3af14
#   experiment_tag: 3_max_depth=5
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 37797
#   should_checkpoint: true
#   time_since_restore: 4.8203630447387695
#   time_this_iter_s: 0.005700111389160156
#   time_total_s: 4.8203630447387695
#   timestamp: 1658339486
#   timesteps_since_restore: 0
#   train-error: 0.0
#   train-logloss: 0.01841634292981527
#   training_iteration: 20
#   trial_id: 8c9fe_00003
#   valid-error: 0.05263157894736842
#   valid-logloss: 0.10578184703239703
#   warmup_time: 0.0027060508728027344
#
# Result for XGBoostTrainer_8c9fe_00004:
#   date: 2022-07-20_10-51-26
#   done: true
#   experiment_id: 515f978fe4ab42639814cb09799a2311
#   experiment_tag: 4_max_depth=3
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 37807
#   should_checkpoint: true
#   time_since_restore: 3.0453381538391113
#   time_this_iter_s: 0.005850076675415039
#   time_total_s: 3.0453381538391113
#   timestamp: 1658339486
#   timesteps_since_restore: 0
#   train-error: 0.0
#   train-logloss: 0.02151511543566108
#   training_iteration: 20
#   trial_id: 8c9fe_00004
#   valid-error: 0.03508771929824561
#   valid-logloss: 0.07659151291540056
#   warmup_time: 0.002939939498901367
#
# Best Result: Result(metrics={'train-logloss': 0.01841634292981527, 'train-error': 0.0, 'valid-logloss': 0.10578184703239703, 'valid-error': 0.05263157894736842, 'time_this_iter_s': 0.005700111389160156, 'should_checkpoint': True, 'done': True, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 20, 'trial_id': '8c9fe_00003', 'experiment_id': 'd4fe8d1c1b3143fcbbb72c60b7c3af14', 'date': '2022-07-20_10-51-26', 'timestamp': 1658339486, 'time_total_s': 4.8203630447387695, 'pid': 37797, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_restore': 4.8203630447387695, 'timesteps_since_restore': 0, 'iterations_since_restore': 20, 'warmup_time': 0.0027060508728027344, 'experiment_tag': '3_max_depth=5'}, checkpoint=<ray.air.checkpoint.Checkpoint object at 0x1663e50a0>, error=None, log_dir=PosixPath('/Users/jules/ray_results/XGBoostTrainer_2022-07-20_10-51-14/XGBoostTrainer_8c9fe_00003_3_max_depth=5_2022-07-20_10-51-20'), metrics_dataframe=    train-logloss  train-error  valid-logloss  valid-error  time_this_iter_s  \
# 0        0.465611     0.022613       0.505882     0.093567          4.623800
# 1        0.332896     0.010050       0.386077     0.052632          0.034805
# 2        0.252007     0.012563       0.326293     0.076023          0.008015
# 3        0.191715     0.010050       0.267602     0.058480          0.007011
# 4        0.149730     0.007538       0.226837     0.052632          0.006730
# 5        0.119332     0.007538       0.198947     0.046784          0.054194
# 6        0.096740     0.005025       0.175565     0.052632          0.006365
# 7        0.078592     0.002513       0.163899     0.052632          0.006871
# 8        0.065687     0.002513       0.155128     0.052632          0.006369
# 9        0.055314     0.002513       0.146913     0.052632          0.006393
# 10       0.047350     0.002513       0.136977     0.052632          0.006023
# 11       0.041698     0.002513       0.133636     0.052632          0.005989
# 12       0.036109     0.002513       0.124063     0.052632          0.005860
# 13       0.032127     0.002513       0.120173     0.052632          0.005873
# 14       0.028889     0.002513       0.116081     0.058480          0.005902
# 15       0.026126     0.000000       0.111825     0.052632          0.005896
# 16       0.023875     0.000000       0.114316     0.058480          0.006273
# 17       0.021785     0.000000       0.112586     0.052632          0.006162
# 18       0.019855     0.000000       0.107597     0.052632          0.006132
# 19       0.018416     0.000000       0.105782     0.052632          0.005700
#
#     should_checkpoint   done  timesteps_total  episodes_total  \
# 0                True  False              NaN             NaN
# 1                True  False              NaN             NaN
# 2                True  False              NaN             NaN
# 3                True  False              NaN             NaN
# 4                True  False              NaN             NaN
# 5                True  False              NaN             NaN
# 6                True  False              NaN             NaN
# 7                True  False              NaN             NaN
# 8                True  False              NaN             NaN
# 9                True  False              NaN             NaN
# 10               True  False              NaN             NaN
# 11               True  False              NaN             NaN
# 12               True  False              NaN             NaN
# 13               True  False              NaN             NaN
# 14               True  False              NaN             NaN
# 15               True  False              NaN             NaN
# 16               True  False              NaN             NaN
# 17               True  False              NaN             NaN
# 18               True  False              NaN             NaN
# 19               True  False              NaN             NaN
#
#     training_iteration  ...                 date   timestamp time_total_s  \
# 0                    1  ...  2022-07-20_10-51-26  1658339486     4.623800
# 1                    2  ...  2022-07-20_10-51-26  1658339486     4.658605
# 2                    3  ...  2022-07-20_10-51-26  1658339486     4.666620
# 3                    4  ...  2022-07-20_10-51-26  1658339486     4.673631
# 4                    5  ...  2022-07-20_10-51-26  1658339486     4.680361
# 5                    6  ...  2022-07-20_10-51-26  1658339486     4.734555
# 6                    7  ...  2022-07-20_10-51-26  1658339486     4.740920
# 7                    8  ...  2022-07-20_10-51-26  1658339486     4.747791
# 8                    9  ...  2022-07-20_10-51-26  1658339486     4.754160
# 9                   10  ...  2022-07-20_10-51-26  1658339486     4.760553
# 10                  11  ...  2022-07-20_10-51-26  1658339486     4.766576
# 11                  12  ...  2022-07-20_10-51-26  1658339486     4.772565
# 12                  13  ...  2022-07-20_10-51-26  1658339486     4.778425
# 13                  14  ...  2022-07-20_10-51-26  1658339486     4.784298
# 14                  15  ...  2022-07-20_10-51-26  1658339486     4.790200
# 15                  16  ...  2022-07-20_10-51-26  1658339486     4.796096
# 16                  17  ...  2022-07-20_10-51-26  1658339486     4.802369
# 17                  18  ...  2022-07-20_10-51-26  1658339486     4.808531
# 18                  19  ...  2022-07-20_10-51-26  1658339486     4.814663
# 19                  20  ...  2022-07-20_10-51-26  1658339486     4.820363
#
#       pid               hostname    node_ip time_since_restore  \
# 0   37797  Juless-MacBook-Pro-16  127.0.0.1           4.623800
# 1   37797  Juless-MacBook-Pro-16  127.0.0.1           4.658605
# 2   37797  Juless-MacBook-Pro-16  127.0.0.1           4.666620
# 3   37797  Juless-MacBook-Pro-16  127.0.0.1           4.673631
# 4   37797  Juless-MacBook-Pro-16  127.0.0.1           4.680361
# 5   37797  Juless-MacBook-Pro-16  127.0.0.1           4.734555
# 6   37797  Juless-MacBook-Pro-16  127.0.0.1           4.740920
# 7   37797  Juless-MacBook-Pro-16  127.0.0.1           4.747791
# 8   37797  Juless-MacBook-Pro-16  127.0.0.1           4.754160
# 9   37797  Juless-MacBook-Pro-16  127.0.0.1           4.760553
# 10  37797  Juless-MacBook-Pro-16  127.0.0.1           4.766576
# 11  37797  Juless-MacBook-Pro-16  127.0.0.1           4.772565
# 12  37797  Juless-MacBook-Pro-16  127.0.0.1           4.778425
# 13  37797  Juless-MacBook-Pro-16  127.0.0.1           4.784298
# 14  37797  Juless-MacBook-Pro-16  127.0.0.1           4.790200
# 15  37797  Juless-MacBook-Pro-16  127.0.0.1           4.796096
# 16  37797  Juless-MacBook-Pro-16  127.0.0.1           4.802369
# 17  37797  Juless-MacBook-Pro-16  127.0.0.1           4.808531
# 18  37797  Juless-MacBook-Pro-16  127.0.0.1           4.814663
# 19  37797  Juless-MacBook-Pro-16  127.0.0.1           4.820363
#
#    timesteps_since_restore  iterations_since_restore  warmup_time
# 0                        0                         1     0.002706
# 1                        0                         2     0.002706
# 2                        0                         3     0.002706
# 3                        0                         4     0.002706
# 4                        0                         5     0.002706
# 5                        0                         6     0.002706
# 6                        0                         7     0.002706
# 7                        0                         8     0.002706
# 8                        0                         9     0.002706
# 9                        0                        10     0.002706
# 10                       0                        11     0.002706
# 11                       0                        12     0.002706
# 12                       0                        13     0.002706
# 13                       0                        14     0.002706
# 14                       0                        15     0.002706
# 15                       0                        16     0.002706
# 16                       0                        17     0.002706
# 17                       0                        18     0.002706
# 18                       0                        19     0.002706
# 19                       0                        20     0.002706
#
# [20 rows x 22 columns], best_checkpoints=[(<ray.air.checkpoint.Checkpoint object at 0x166320f70>, {'train-logloss': 0.465611254524945, 'train-error': 0.02261306532663317, 'valid-logloss': 0.5058815336366843, 'valid-error': 0.0935672514619883, 'time_this_iter_s': 4.623799800872803, 'should_checkpoint': True, 'done': False, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 1, 'trial_id': '8c9fe_00003', 'experiment_id': 'd4fe8d1c1b3143fcbbb72c60b7c3af14', 'date': '2022-07-20_10-51-26', 'timestamp': 1658339486, 'time_total_s': 4.623799800872803, 'pid': 37797, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_restore': 4.623799800872803, 'timesteps_since_restore': 0, 'iterations_since_restore': 1, 'warmup_time': 0.0027060508728027344, 'experiment_tag': '3_max_depth=5'}), (<ray.air.checkpoint.Checkpoint object at 0x169d87e80>, {'train-logloss': 0.33289550244808197, 'train-error': 0.01005025125628141, 'valid-logloss': 0.3860774944748795, 'valid-error': 0.05263157894736842, 'time_this_iter_s': 0.0348050594329834, 'should_checkpoint': True, 'done': False, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 2, 'trial_id': '8c9fe_00003', 'experiment_id': 'd4fe8d1c1b3143fcbbb72c60b7c3af14', 'date': '2022-07-20_10-51-26', 'timestamp': 1658339486, 'time_total_s': 4.658604860305786, 'pid': 37797, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_restore': 4.658604860305786, 'timesteps_since_restore': 0, 'iterations_since_restore': 2, 'warmup_time': 0.0027060508728027344, 'experiment_tag': '3_max_depth=5'}), (<ray.air.checkpoint.Checkpoint object at 0x169d61be0>, {'train-logloss': 0.2520069157583031, 'train-error': 0.01256281407035176, 'valid-logloss': 0.3262928800973279, 'valid-error': 0.07602339181286549, 'time_this_iter_s': 0.008014917373657227, 'should_checkpoint': True, 'done': False, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 3, 'trial_id': '8c9fe_00003', 'experiment_id': 'd4fe8d1c1b3143fcbbb72c60b7c3af14', 'date': '2022-07-20_10-51-26', 'timestamp': 1658339486, 'time_total_s': 4.666619777679443, 'pid': 37797, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_restore': 4.666619777679443, 'timesteps_since_restore': 0, 'iterations_since_restore': 3, 'warmup_time': 0.0027060508728027344, 'experiment_tag': '3_max_depth=5'}), (<ray.air.checkpoint.Checkpoint object at 0x169d5ebb0>, {'train-logloss': 0.19171511336936423, 'train-error': 0.01005025125628141, 'valid-logloss': 0.26760199273887436, 'valid-error': 0.05847953216374269, 'time_this_iter_s': 0.0070111751556396484, 'should_checkpoint': True, 'done': False, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 4, 'trial_id': '8c9fe_00003', 'experiment_id': 'd4fe8d1c1b3143fcbbb72c60b7c3af14', 'date': '2022-07-20_10-51-26', 'timestamp': 1658339486, 'time_total_s': 4.673630952835083, 'pid': 37797, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_restore': 4.673630952835083, 'timesteps_since_restore': 0, 'iterations_since_restore': 4, 'warmup_time': 0.0027060508728027344, 'experiment_tag': '3_max_depth=5'}), (<ray.air.checkpoint.Checkpoint object at 0x169e37370>, {'train-logloss': 0.14972986310870204, 'train-error': 0.00753768844221105, 'valid-logloss': 0.22683743971307374, 'valid-error': 0.05263157894736842, 'time_this_iter_s': 0.006730079650878906, 'should_checkpoint': True, 'done': False, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 5, 'trial_id': '8c9fe_00003', 'experiment_id': 'd4fe8d1c1b3143fcbbb72c60b7c3af14', 'date': '2022-07-20_10-51-26', 'timestamp': 1658339486, 'time_total_s': 4.680361032485962, 'pid': 37797, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_rest ...

# %% [markdown]
# ### Create a `BatchPreditor` for batch prediction
# Once you have trained and tuned your model, create a batch predictor from best model using the `best_result.checkpoint` and do batch inference.

# %%
from ray.train.batch_predictor import BatchPredictor
from ray.train.xgboost import XGBoostPredictor

batch_predictor = BatchPredictor.from_checkpoint(best_result.checkpoint, XGBoostPredictor)

predicted_probabilities = batch_predictor.predict(test_dataset)
print("PREDICTED PROBABILITIES")
predicted_probabilities.show()
# Out:
# Map Progress (1 actors 1 pending): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.38it/s]
# PREDICTED PROBABILITIES
# {'predictions': 0.9960426092147827}
# {'predictions': 0.9957077503204346}
# {'predictions': 0.0034389763604849577}
# {'predictions': 0.9962536096572876}
# {'predictions': 0.9968380928039551}
# {'predictions': 0.9957551956176758}
# {'predictions': 0.9920042157173157}
# {'predictions': 0.994161069393158}
# {'predictions': 0.2891101539134979}
# {'predictions': 0.974367082118988}
# {'predictions': 0.0034389763604849577}
# {'predictions': 0.9959942102432251}
# {'predictions': 0.9474029541015625}
# {'predictions': 0.9923243522644043}
# {'predictions': 0.9941523671150208}
# {'predictions': 0.1239369809627533}
# {'predictions': 0.5043733716011047}
# {'predictions': 0.9935414791107178}
# {'predictions': 0.9832899570465088}
# {'predictions': 0.0034389763604849577}

# %% [markdown]
# ### Create `PredictorDeployment` for Online Inference
#
# Deploy the best model as an inference service by using Ray Serve and the `PredictorDeployment` class.

# %%
from ray import serve
from fastapi import Request
from ray.serve import PredictorDeployment
from ray.serve.http_adapters import json_request


async def adapter(request: Request):
    content = await request.json()
    print(content)
    return pd.DataFrame.from_dict(content)


serve.start(detached=True)
deployment = PredictorDeployment.options(name="XGBoostService")

deployment.deploy(
    XGBoostPredictor, best_result.checkpoint, batching_params=False, http_adapter=adapter
)

print(deployment.url)
# Out:
# (ServeController pid=37930) INFO 2022-07-20 10:51:47,280 controller 37930 checkpoint_path.py:17 - Using RayInternalKVStore for controller checkpoint and recovery.
# (ServeController pid=37930) INFO 2022-07-20 10:51:47,300 controller 37930 http_state.py:123 - Starting HTTP proxy with name 'SERVE_CONTROLLER_ACTOR:SERVE_PROXY_ACTOR-9636fa263e340aa24cb609b086fee61a841cb0258492f120360b1dc5' on node '9636fa263e340aa24cb609b086fee61a841cb0258492f120360b1dc5' listening on '127.0.0.1:8000'
# (HTTPProxyActor pid=37932) INFO:     Started server process [37932]
# (ServeController pid=37930) INFO 2022-07-20 10:51:47,921 controller 37930 deployment_state.py:1280 - Adding 1 replicas to deployment 'XGBoostService'.
# http://127.0.0.1:8000/XGBoostService

# %% [markdown]
# After deploying the service, you can send requests to it.

# %%
import requests

sample_input = test_dataset.take(1)
sample_input = dict(sample_input[0])

output = requests.post(deployment.url, json=[sample_input]).json()
print(output)
# Out:
# [{'predictions': 0.9960426092147827}]
# (ServeReplica:XGBoostService pid=37934) [{'mean radius': 11.06, 'mean texture': 14.83, 'mean perimeter': 70.31, 'mean area': 378.2, 'mean smoothness': 0.07741, 'mean compactness': 0.04768, 'mean concavity': 0.02712, 'mean concave points': 0.007246, 'mean symmetry': 0.1535, 'mean fractal dimension': 0.06214, 'radius error': 0.1855, 'texture error': 0.6881, 'perimeter error': 1.263, 'area error': 12.98, 'smoothness error': 0.004259, 'compactness error': 0.01469, 'concavity error': 0.0194, 'concave points error': 0.004168, 'symmetry error': 0.01191, 'fractal dimension error': 0.003537, 'worst radius': 12.68, 'worst texture': 20.35, 'worst perimeter': 80.79, 'worst area': 496.7, 'worst smoothness': 0.112, 'worst compactness': 0.1879, 'worst concavity': 0.2079, 'worst concave points': 0.05556, 'worst symmetry': 0.259, 'worst fractal dimension': 0.09158}]
# (HTTPProxyActor pid=37932) INFO 2022-07-20 10:51:54,106 http_proxy 127.0.0.1 http_proxy.py:315 - POST /XGBoostService 307 5.4ms
# (HTTPProxyActor pid=37932) INFO 2022-07-20 10:51:54,114 http_proxy 127.0.0.1 http_proxy.py:315 - POST /XGBoostService 200 6.6ms
# (ServeReplica:XGBoostService pid=37934) INFO 2022-07-20 10:51:54,104 XGBoostService XGBoostService#kLSUrh replica.py:478 - HANDLE __call__ OK 0.3ms
# (ServeReplica:XGBoostService pid=37934) INFO 2022-07-20 10:51:54,114 XGBoostService XGBoostService#kLSUrh replica.py:478 - HANDLE __call__ OK 4.7ms

# %%
ray.shutdown()

# %% [markdown]
# ### Homework
#
# 1. Have a go at Ray AIR examples in the documentation.
